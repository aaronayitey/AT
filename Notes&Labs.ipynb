# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="text-align:center">
#
# # Python Basics
#
# </div>

# %% [markdown]
# This lesson covers:
# 1. Programming
# 2. Python
# 3. IDEs
# 4. Variables and Data types
# 5. Operators and Operations
# 6. Basic input and Output
# 7. Handling strings

# %% [markdown]
# Programming…
#
# A program is a set of instructions that do computing tasks.
#
# Programming is the act of writing instructions for a computer to create an app or perform a task.
#
# A Programing Language  is a set of vocabulary and syntax  for instructing a computer device to perform a  task.
#
# Syntax of a programming language includes keywords (reserved words), operators, and grammar rules used in programming.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Python <br>
# What is python? <br>
# Python is an interpreted, object-oriented, high-level programming language with dynamic semantics.
#
# Why Python?
# *   It’s easy to learn
# *   It’s open source
# *   It has large community making it easy to get assistance in time of need
# *   It’s a general programming language
# *   It works on almost all operating systems

# %% [markdown]
# How  python works <br>
# Python has an interpreter.
#
# The python compiler turns codes into a special format that a Python interpreter can interpret and run.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Variables and Data types
#
#
# Some few things to note in python programming
# *  case sensitive
# *  spacing
# *  errors
# *  print function
# *  variable naming

# %% [markdown]
# # Variable Naming

# %%
# Python operates with zero index
# Get an output with my name
# A place holder
# Reserved key words
# Strings are always put in quotation marks
# Numerals don't use quotation markss. So are booleans(True/False)
student_list = ["Stella","Kwesi", "Isaac", "Jona"]
# my_dict = {}
# name, age
# message = 'Hey, call me Setella'
# methods
print('Hey, call me', student_list[3])
# Out:
# Hey, call me Jona

# %%
student_list[1].upper()
# Out:
# 'KWESI'

# %%
example = "There are built methods and operators."
new_example = example.split(" ")
new_example
# Out:
# ['There', 'are', 'built', 'methods', 'and', 'operators.']

# %%
new_example[0].split('m')
# Out:
# ['There']

# %%
your_string = "There are built methods and operators."

# %%
example2=your_string.split(" ")

# %%
example2
# Out:
# ['There', 'are', 'built', 'methods', 'and', 'operators.']

# %%
type(example2)
# Out:
# list

# %%
ysyper=your_string.upper()

# %%
ysyper
# Out:
# 'THERE ARE BUILT METHODS AND OPERATORS.'

# %%
ysyper.replace('ARE', 'is')
# Out:
# 'THERE is BUILT METHODS AND OPERATORS.'

# %%
new_string = "female and male"

# %%
scale_string = ["strongly disagree", "disagree",  "neutral", "agree", "strongly agree"]

# %%
my_scale = {1:"strongly disagree", 2:"disagree", 3: "neutral", 4: "agree", 5: "strongly agree"}

# %%
# 'for' loop
# while loop

for i in scale_string:
    print(i)
# Out:
# strongly disagree
# disagree
# neutral
# agree
# strongly agree

# %%
# x = 8
# while x < 11:
#     print("I'm in a while loop")
#     x = x - 1
# Cntrol + /

# %%
scale_string = ["strongly disagree", "disagree",  "neutral", "agree", "strongly agree"]

# %%
num_scale = {"strongly disagree":1, "disagree": 2,  "neutral":3, "agree":4, "strongly agree": 5}

# %%
# dictionary is a collection of data types as keys, value pairs
#  Looping througn a list scale_string
#  double equals (==) for comparism
#  one equal is for asigning values
#  for any statement that needs something else to be done, we end it with : (colon)
scale_string = ["strongly disagree", "disagree",  "neutral", "agree", "strongly agree"]
num_scale = {"strongly disagree":1, "disagree": 2,  "neutral":3, "agree":4, "strongly agree": 5}

my_scale_num = []
for scale in scale_string:
    for key,value in num_scale.items():
        if scale == key:
            my_scale_num.append(value)

# %%
my_scale_num
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## String Indexing

# %%
scale_string
# Out:
# ['strongly disagree', 'disagree', 'neutral', 'agree', 'strongly agree']

# %%
# Square brackets is used for indexing 
# Python uses zero-indexing but neglects the last index unless you add 1 to the end. Other option is to leave the end point empty.
# two double dots and -1 reverses everything in the list
# specifying just -1 index gives you the last item. Meaning is; it gives you the reverse of first item.
# So is -2 etc which starts from the last. Thus 2 from the last item.


scale_string[::-1]
# Out:
# ['strongly agree', 'agree', 'neutral', 'disagree', 'strongly disagree']

# %%
len(scale_string)
# Out:
# 5

# %% [markdown]
# <!-- methods vs functions -->
# ....upper() <br>
# len(scale_string) <br>
# print() <br>
# print(scale_string)

# %% [markdown]
# ## String Formatting

# %%
scale_string
# Out:
# ['strongly disagree', 'disagree', 'neutral', 'agree', 'strongly agree']

# %%
print('The categorical scales are:\n', scale_string)
# Out:
# The categorical scales are:
#  ['strongly disagree', 'disagree', 'neutral', 'agree', 'strongly agree']

# %%
print('The categorical scales are:\n', my_scale_num)
# Out:
# The categorical scales are:
#  [1, 2, 3, 4, 5]

# %%
print('I\'m good.') # '\' called the backslash symbol is an escape character which let python ignores the extra ' in front of it as in the example. Note: '\n' prints characters in its front in a new line.
# Out:
# I'm good.

# %%
age = 45
print("My age is ", age)
# Out:
# My age is  45

# %%
print(("I'm"), age, ("years old"))
# Out:
# I'm 45 years old

# %%
age = 45.55888

# %%
age
# Out:
# 45.55888

# %% [markdown]
# Mothod 1: f' string formatting

# %%
amount = 100000

# %%
print(f"I have {amount:,}")
# Out:
# I have 100,000

# %% [markdown]
# The .format() method

# %%
print("I'm {} years old.".format(round(age))) # The curly bracket
# Out:
# I'm 46 years old.

# %%
print("I'm rounding {}".format(round(age, 2)))
# Out:
# I'm rounding 45.56

# %%
print("I am {} years old and I have {} USD".format(round(age,2), round(float(amount), 4)))
# Out:
# I am 45.56 years old and I have 100000.0 USD

# %%
my_list = []
my_list.append(1)

# %%
my_list
# Out:
# [1]

# %%
lst = []
lst = list()

# %%
my_dict = {}
my_dict = dict()

# %% [markdown]
# # Sets

# %% [markdown]
# Used to harbour unique items. It is also denoted with {}

# %%
my_set = {}
my_set = set()

# %%
countries = ['Sudan', 'Egypt', 'Togo', 'Egypt', 'Ghana', 'Togo']

countries_set = set(countries) # Type casting

# %%
type(countries)
# Out:
# list

# %%
type(countries_set)
# Out:
# set

# %%
countries_set
# Out:
# {'Egypt', 'Ghana', 'Sudan', 'Togo'}

# %% [markdown]
# Tuple

# %% [markdown]
# A list that cannot be `modified`. It is therefore termed `ummutable`

# %%
my_tup = ('Aaron', "another name")
my_tup[1]
# Out:
# 'another name'

# %% [markdown]
# ## More on Comparison Operators

# %% [markdown]
# Comparison operators, also known as relational operators, are used to compare values and determine the relationship between them. They are commonly used in conditional statements, loops, and other programming constructs. Here are the most common comparison operators and their meanings
#
#
# They are:<br>
# * equal to ==
# * less or equal to <=
# * greater or equal to >=
# * less than   <
# * greater than >
# * not equal to !=

# %%
x = 5
y = 1+4

# %%
x == y # comparing x to y...returns True/False
# Out:
# True

# %%
x != y #otherwise
# Out:
# False

# %% [markdown]
# ## User Input

# %% [markdown]
# Function that accepts input from user <br>
# Input can be:
# * string
# * integer
# * float
# * bolean

# %%
name = input("Please enter your name: ")

# %%
name
# Out:
# 'Aaron'

# %% [markdown]
# ## Conditionals ......if, elif, else

# %% [markdown]
# Conditionals, also known as "if-else statements," are fundamental constructs in programming and computer science. They allow us to create decision-making logic in our code. Conditionals enable the program to make different decisions or execute different code blocks based on whether certain conditions are `true` or `false`.

# %%
The structure: single condition


if condition:
    # Code block to execute if the condition is true

else:
    # Code block to execute if the condition is false

# %%
Multiple conditions

if condition1:
    # Code block to execute if condition1 is true
elif condition2:
    # Code block to execute if condition2 is true
else:
    # Code block to execute if both condition1 and condition2 are false

# %% [markdown]
# Example 1: Checking if a Number is Positive or Negative

# %%
number = float(input("Enter a number"))

if number >0:
    print(f"{number} is positive")

elif number == 0:
    print(f"{number}  is 0")

else:
    print(f"{number} is negative")
# Out:
# 0.0  is 0

# %% [markdown]
# Example 3: Determining the Largest Number

# %%
number1 = 5
number2 = 14
number3 = 1

# %% [markdown]
# and  or

# %%
if number1 >= number2 and number1 >= number3:
    largest_number = number1
elif number2 >= number1 and number2 >= number3:
    largest_number = number2
else:
    largest_number = number3

# %%
largest_number
# Out:
# 14

# %% [markdown]
# Example 4: Checking for Leap Year

# %%
year = 2023
# a leap year is divissible by 4 but not 100.... year%4 == 0 and year%100 != 0
# a leap year is divissible by 400 modulo (%) ....year%400 == 0

if (year%4 == 0 and year%100 != 0) or (year%400 ==0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is a common year")
# Out:
# 2023 is a common year

# %% [markdown]
# Example 5: Checking Username and Password
